# %% [markdown]
# Checking data types and dataset arrangements

# %% [markdown]
# ### Importing library

# %%
import pandas as pd

# %% [markdown]
# ### Importing datasets

# %% [markdown]
# #### Basic Stage

# %%
obts_basic = pd.read_csv("data/obts/obts_basic.csv")
obts_basic.info()
# Out:
# C:\Users\sdasgupta\AppData\Local\Temp\ipykernel_9512\3138490787.py:1: DtypeWarning: Columns (2,13) have mixed types. Specify dtype option on import or set low_memory=False.
#   obts_basic = pd.read_csv("data/obts/obts_basic.csv")
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 18341486 entries, 0 to 18341485
# Data columns (total 18 columns):
#  #   Column            Dtype
# ---  ------            -----
#  0   id                int64
#  1   Message_Type      object
#  2   Off_Tran_No       object
#  3   Court_Docket_No   object
#  4   Sequence_No       int64
#  5   No_of_Counts      int64
#  6   Court_Designator  object
#  7   County            int64
#  8   Arrest_Name       object
#  9   Final_name        object
#  10  Sex               object
#  11  Race              object
#  12  birth_date        float64
#  13  Init_Arrest_Dt    object
#  14  Clerk_Dt          int64
#  15  Offense_Dt        float64
#  16  Capias_Dt         int64
#  17  Rearrest_Dt       int64
# ...

# %%
obts_basic.columns = obts_basic.columns.str.upper()
obts_basic
# Out:
#                 ID MESSAGE_TYPE OFF_TRAN_NO       COURT_DOCKET_NO  \
# 0                1            N  8888888888  011991CF000568XXXAXX
# 1                2            N  8888888888  011991CF000568XXXAXX
# 2                3            N  8888888888  011995CF003385XXXAXX
# 3                4            N  8888888888  011999CF003366XXXAXX
# 4                5            N   108009684  011999CT000044XXXAXX
# ...            ...          ...         ...                   ...
# 18341481  18341482            N  8888888888  672024MM000008MMAXMX
# 18341482  18341483            N  8888888888  672024MM000009MMAXMX
# 18341483  18341484            N  8888888888  672024MM000010MMAXMX
# 18341484  18341485            N  8888888888  672024MM000011MMAXMX
# 18341485  18341486            N  8888888888  672024MM000017MMAXMX
#
#           SEQUENCE_NO  NO_OF_COUNTS COURT_DESIGNATOR  COUNTY  \
# 0                   1             1                R       1
# ...

# %% [markdown]
# #### Initial Stage

# %%
obts_initial = pd.read_csv("data/obts/obts_initial.csv")
obts_initial.info()
# Out:
# C:\Users\sdasgupta\AppData\Local\Temp\ipykernel_9512\4122048403.py:1: DtypeWarning: Columns (4,5,8) have mixed types. Specify dtype option on import or set low_memory=False.
#   obts_initial = pd.read_csv("data/obts/obts_initial.csv")
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 18341486 entries, 0 to 18341485
# Data columns (total 10 columns):
#  #   Column              Dtype
# ---  ------              -----
#  0   id                  int64
#  1   In_Charge_Status    object
#  2   Charge_Level        object
#  3   Charge_Degree       object
#  4   in_FLST_Chap        object
#  5   in_FLST_Sect        object
#  6   in_FLST_Subsect     object
#  7   Drug_Type           object
#  8   Bond_Hearing_Dt     object
#  9   Adv_Prelim_Hear_Dt  float64
# dtypes: float64(1), int64(1), object(8)
# memory usage: 1.4+ GB

# %%
obts_initial.columns = obts_initial.columns.str.upper()
obts_initial
# Out:
#                 ID IN_CHARGE_STATUS CHARGE_LEVEL CHARGE_DEGREE IN_FLST_CHAP  \
# 0                1                S            F             T        893.0
# 1                2                S            F             S        893.0
# 2                3                N          NaN           NaN          NaN
# 3                4                S            F             T        893.0
# 4                5                F            M             S        322.0
# ...            ...              ...          ...           ...          ...
# 18341481  18341482                P            M             S        379.0
# 18341482  18341483                P            M             S        379.0
# 18341483  18341484                S            M             S        379.0
# 18341484  18341485                P            M             S        379.0
# 18341485  18341486                F            M             F        784.0
#
# ...

# %% [markdown]
# #### Prosecutor Stage

# %%
obts_prosecutor = pd.read_csv("data/obts/obts_prosecutor.csv")
obts_prosecutor.info()
# Out:
# C:\Users\sdasgupta\AppData\Local\Temp\ipykernel_9512\2457777056.py:1: DtypeWarning: Columns (5,6,8,9,11) have mixed types. Specify dtype option on import or set low_memory=False.
#   obts_prosecutor = pd.read_csv("data/obts/obts_prosecutor.csv")
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 18289409 entries, 0 to 18289408
# Data columns (total 12 columns):
#  #   Column                Dtype
# ---  ------                -----
#  0   id                    int64
#  1   pr_Charge_Status      object
#  2   pr_Charge_Level       object
#  3   pr_Charge_Degree      object
#  4   pr_Gen_Off_Char       object
#  5   pr_FLST_Chap          object
#  6   pr_FLST_Sect          object
#  7   pr_FLST_Subsect       object
#  8   pr_Filing_Dt          object
#  9   pr_Final_Decision_Dt  object
#  10  pr_Final_Action       object
#  11  pr_Counsel_Type       object
# dtypes: int64(1), object(11)
# memory usage: 1.6+ GB

# %%
obts_prosecutor.columns = obts_prosecutor.columns.str.upper()
obts_prosecutor
# Out:
#                 ID PR_CHARGE_STATUS PR_CHARGE_LEVEL PR_CHARGE_DEGREE  \
# 0                1                S               F                T
# 1                2                S               F                S
# 2                3                E               F                T
# 3                4                S               F                T
# 4                5              NaN             NaN              NaN
# ...            ...              ...             ...              ...
# 18289404  18341482                S               M                S
# 18289405  18341483                S               M                S
# 18289406  18341484                S               M                S
# 18289407  18341485                N               N                N
# 18289408  18341486                N               N                N
#
#          PR_GEN_OFF_CHAR PR_FLST_CHAP PR_FLST_SECT PR_FLST_SUBSECT  \
# 0                      N        893.0           13               1
# ...
